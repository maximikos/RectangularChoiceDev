# %%
using CSV
using DataFrames

# %%
CSV.File("../data/processed/exio3_agg/IOT_2022_pxp/A.txt"; delim='\t')
# Out:
# 202-element CSV.File:
# ...

# %%
file = CSV.File("../data/processed/exio3_agg/IOT_2022_pxp/A.txt"; delim='\t')
file|>CSV.Tables.matrix
# Out:
# 202×202 Matrix{Union{Missing, String}}:
#  "sector"  …  "Extra-territorial organizations and bodies"
#  "region"     missing
#  "global"     "0"
#  "global"     "0"
#  "global"     "0"
#  "global"  …  "0"
#  "global"     "0"
#  "global"     "0"
#  "global"     "0"
#  "global"     "0"
#  "global"  …  "0"
#  "global"     "0"
#  "global"     "0"
#  ⋮         ⋱
#  "global"  …  "0"
#  "global"     "0"
#  "global"     "0"
#  "global"     "0"
#  "global"     "0"
#  "global"  …  "0"
#  "global"     "0"
#  "global"     "0"
#  "global"     "0"
#  "global"     "0"
#  "global"  …  "0"
#  "global"     "0"

# %%
CSV.read("../data/processed/exio3_agg/IOT_2022_pxp/x.txt", DataFrame; delim='\t')
# Out:
# 200×3 DataFrame
#  Row │ region   sector                             indout
#      │ String7  String                             Float64
# ─────┼────────────────────────────────────────────────────────────
#    1 │ global   Paddy rice                              3.27325e5
#    2 │ global   Wheat                                   2.56997e5
#    3 │ global   Cereal grains nec                       4.15533e5
#    4 │ global   Vegetables, fruit, nuts                 1.26791e6
#    5 │ global   Oil seeds                               2.33755e5
#    6 │ global   Sugar cane, sugar beet                  1.05384e5
#    7 │ global   Plant-based fibers                      1.25948e5
#    8 │ global   Crops nec                               5.82012e5
#    9 │ global   Cattle                                  2.85374e5
#   10 │ global   Pigs                                    3.48661e5
#   11 │ global   Poultry                            351228.0
# ...

# %%
CSV.read("../data/processed/exio3_agg/IOT_2022_pxp/x.txt", fill; delim='\t')
# Out:
# 0-dimensional Array{Tables.CopiedColumns{CSV.File}, 0}:
# Tables.CopiedColumns{CSV.File} with 200 rows, 3 columns, and schema:
#  :region  String7
#  :sector  String
#  :indout  Float64

# %%
using DelimitedFiles
readdlm("../data/processed/exio3_agg/IOT_2022_pxp/x.txt", '\t')
# Out:
# 201×3 Matrix{Any}:
#  "region"  …        "indout"
#  "global"          3.27325e5
#  "global"          2.56997e5
#  "global"          4.15533e5
#  "global"          1.26791e6
#  "global"  …       2.33755e5
#  "global"          1.05384e5
#  "global"          1.25948e5
#  "global"          5.82012e5
#  "global"          2.85374e5
#  "global"  …       3.48661e5
#  "global"     351228.0
#  "global"      90820.1
#  ⋮         ⋱
#  "global"     264602.0
#  "global"  …       1.63747e5
#  "global"      90561.9
#  "global"      55210.9
#  "global"      95398.1
#  "global"      27223.7
#  "global"  …   34158.3
#  "global"          1.09227e6
#  "global"          2.26207e6
#  "global"          1.69894e6
#  "global"          3.37206e5
#  "global"  …       0
